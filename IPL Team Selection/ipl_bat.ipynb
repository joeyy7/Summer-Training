# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %% [markdown]
#  Read batting status in ipl

# %%
data=pd.read_csv(r"D:\Summer-Training\IPL Team Selection\IPL Player Stats\Batting Stats\BATTING STATS - IPL_2016.csv")
data1=pd.read_csv(r"D:\Summer-Training\IPL Team Selection\IPL Player Stats\Batting Stats\BATTING STATS - IPL_2017.csv")
data2=pd.read_csv(r"D:\Summer-Training\IPL Team Selection\IPL Player Stats\Batting Stats\BATTING STATS - IPL_2018.csv")
data3=pd.read_csv(r"D:\Summer-Training\IPL Team Selection\IPL Player Stats\Batting Stats\BATTING STATS - IPL_2019.csv")
data4=pd.read_csv(r"D:\Summer-Training\IPL Team Selection\IPL Player Stats\Batting Stats\BATTING STATS - IPL_2020.csv")
data5=pd.read_csv(r"D:\Summer-Training\IPL Team Selection\IPL Player Stats\Batting Stats\BATTING STATS - IPL_2021.csv")
data6=pd.read_csv(r"D:\Summer-Training\IPL Team Selection\IPL Player Stats\Batting Stats\BATTING STATS - IPL_2022.csv")
data7=pd.read_csv(r"D:\Summer-Training\IPL Team Selection\IPL Player Stats\Bowling Stats\BOWLING STATS - IPL_2016.csv")
data8=pd.read_csv(r"D:\Summer-Training\IPL Team Selection\IPL Player Stats\Bowling Stats\BOWLING STATS - IPL_2017.csv")
data9=pd.read_csv(r"D:\Summer-Training\IPL Team Selection\IPL Player Stats\Bowling Stats\BOWLING STATS - IPL_2018.csv")
data10=pd.read_csv(r"D:\Summer-Training\IPL Team Selection\IPL Player Stats\Bowling Stats\BOWLING STATS - IPL_2019.csv")
data11=pd.read_csv(r"D:\Summer-Training\IPL Team Selection\IPL Player Stats\Bowling Stats\BOWLING STATS - IPL_2020.csv")
data12=pd.read_csv(r"D:\Summer-Training\IPL Team Selection\IPL Player Stats\Bowling Stats\BOWLING STATS - IPL_2021.csv")
data13=pd.read_csv(r"D:\Summer-Training\IPL Team Selection\IPL Player Stats\Bowling Stats\BOWLING STATS - IPL_2022.csv")

# %%
ipl_batting=pd.concat([data,data1,data2,data3,data4,data5,data6])
ipl_bowler=pd.concat([data7,data8,data9,data10,data11,data12,data13])

# %%
ipl_batting.isnull().sum()
# Out:
# POS       0
# Player    0
# Mat       0
# Inns      0
# NO        0
# Runs      0
# HS        0
# Avg       0
# BF        0
# SR        0
# 100       0
# 50        0
# 4s        0
# 6s        0
# dtype: int64

# %%
ipl_bowler.isnull().sum()
# Out:
# POS       0
# Player    0
# Mat       0
# Inns      0
# Ov        0
# Runs      0
# Wkts      0
# BBI       0
# Avg       0
# Econ      0
# SR        0
# 4w        0
# 5w        0
# dtype: int64

# %% [markdown]
# We pick 13 batter and 12 bowlers

# %% [markdown]
# First of all we find best  batting stats in ipl

# %%
player_name="Player"
player_name
# Out:
# 'Player'

# %%
player_data=data[data['Player']==player_name]
player_data
# Out:
# Empty DataFrame
# Columns: [POS, Player, Mat, Inns, NO, Runs, HS, Avg, BF, SR, 100, 50, 4s, 6s]
# Index: []

# %%
combined_data=pd.DataFrame()

# %%
#filter the data
batting_data=ipl_batting[['Player','Runs']]
batting_data
# Out:
#                   Player  Runs
# 0            Virat Kohli   973
# 1           David Warner   848
# 2         AB de Villiers   687
# 3         Gautam Gambhir   501
# 4         Shikhar Dhawan   501
# ..                   ...   ...
# 157     Fazalhaq Farooqi     2
# 158   Jagadeesha Suchith     2
# 159          Tim Southee     2
# 160  Nathan Coulter-Nile     1
# 161        Anrich Nortje     1
#
# [1005 rows x 2 columns]

# %%
batting_status=batting_data.groupby('Player').agg({'Runs':'sum'})

# %%
combined_data=combined_data.append(batting_data)
# Out:
# C:\Users\a\AppData\Local\Temp\ipykernel_2780\1011591193.py:1: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   combined_data=combined_data.append(batting_data)

# %%
batter_runs=combined_data.groupby('Player')['Runs'].sum()

# %%
top_batter=batter_runs.nlargest(13)

# %%
top_batter
# Out:
# Player
# Shikhar Dhawan      3663
# Virat Kohli         3487
# David Warner        3356
# KL Rahul            2945
# Rishabh Pant        2838
# Jos Buttler         2831
# Sanju Samson        2777
# AB de Villiers      2592
# Rohit Sharma        2494
# Shreyas Iyer        2337
# Suryakumar Yadav    2323
# Ambati Rayudu       2199
# Nitish Rana         2181
# Name: Runs, dtype: int64

# %%
batting_data=ipl_batting[['Player','Runs']]
trend=batting_data.value_counts()['Shikhar Dhawan']
plt.plot(trend.index)

# %%
batting_data=ipl_batting[['Player','Runs']]
trend=batting_data.value_counts()['Virat Kohli']
plt.plot(trend.index)

# %%
batting_data=ipl_batting[['Player','Runs']]
trend=batting_data.value_counts()['David Warner']
plt.plot(trend.index)

# %%
batting_data=ipl_batting[['Player','Runs']]
trend=batting_data.value_counts()['KL Rahul']
plt.plot(trend.index)

# %%
batting_data=ipl_batting[['Player','Runs']]
trend=batting_data.value_counts()['Rishabh Pant']
plt.plot(trend.index)

# %%
batting_data=ipl_batting[['Player','Runs']]
trend=batting_data.value_counts()['Jos Buttler']
plt.plot(trend.index)

# %%
batting_data=ipl_batting[['Player','Runs']]
trend=batting_data.value_counts()['Sanju Samson']
plt.plot(trend.index)

# %%
batting_data=ipl_batting[['Player','Runs']]
trend=batting_data.value_counts()['AB de Villiers']
plt.plot(trend.index)

# %%
batting_data=ipl_batting[['Player','Runs']]
trend=batting_data.value_counts()['Rohit Sharma']
plt.plot(trend.index)

# %%
batting_data=ipl_batting[['Player','Runs']]
trend=batting_data.value_counts()['Shreyas Iyer']
plt.plot(trend.index)

# %%
batting_data=ipl_batting[['Player','Runs']]
trend=batting_data.value_counts()['Suryakumar Yadav']
plt.plot(trend.index)

# %%
batting_data=ipl_batting[['Player','Runs']]
trend=batting_data.value_counts()['Ambati Rayudu']
plt.plot(trend.index)

# %%
batting_data=ipl_batting[['Player','Runs']]
trend=batting_data.value_counts()['Nitish Rana']
plt.plot(trend.index)
