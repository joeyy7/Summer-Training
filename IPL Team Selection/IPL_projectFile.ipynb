# %%
#import libraries
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
data=pd.read_csv(r"D:\Summer-Training\IPL Team Selection\IPL Player Stats\Bowling Stats\BOWLING STATS - IPL_2016.csv")
data2=pd.read_csv(r"D:\Summer-Training\IPL Team Selection\IPL Player Stats\Bowling Stats\BOWLING STATS - IPL_2017.csv")
data3=pd.read_csv(r"D:\Summer-Training\IPL Team Selection\IPL Player Stats\Bowling Stats\BOWLING STATS - IPL_2018.csv")
data4=pd.read_csv(r"D:\Summer-Training\IPL Team Selection\IPL Player Stats\Bowling Stats\BOWLING STATS - IPL_2019.csv")
data5=pd.read_csv(r"D:\Summer-Training\IPL Team Selection\IPL Player Stats\Bowling Stats\BOWLING STATS - IPL_2020.csv")
data6=pd.read_csv(r"D:\Summer-Training\IPL Team Selection\IPL Player Stats\Bowling Stats\BOWLING STATS - IPL_2021.csv")
data7=pd.read_csv(r"D:\Summer-Training\IPL Team Selection\IPL Player Stats\Bowling Stats\BOWLING STATS - IPL_2022.csv")
data8=pd.read_csv(r"D:\Summer-Training\IPL Team Selection\IPL Player Stats\Batting Stats\BATTING STATS - IPL_2016.csv")
data9=pd.read_csv(r"D:\Summer-Training\IPL Team Selection\IPL Player Stats\Batting Stats\BATTING STATS - IPL_2017.csv")
data10=pd.read_csv(r"D:\Summer-Training\IPL Team Selection\IPL Player Stats\Batting Stats\BATTING STATS - IPL_2018.csv")
data11=pd.read_csv(r"D:\Summer-Training\IPL Team Selection\IPL Player Stats\Batting Stats\BATTING STATS - IPL_2019.csv")
data12=pd.read_csv(r"D:\Summer-Training\IPL Team Selection\IPL Player Stats\Batting Stats\BATTING STATS - IPL_2020.csv")
data13=pd.read_csv(r"D:\Summer-Training\IPL Team Selection\IPL Player Stats\Batting Stats\BATTING STATS - IPL_2021.csv")
data14=pd.read_csv(r"D:\Summer-Training\IPL Team Selection\IPL Player Stats\Batting Stats\BATTING STATS - IPL_2022.csv")

# %%
ipldata_bowlers=pd.concat([data,data2,data3,data4,data5,data6,data7])
ipldata_batters=pd.concat([data8,data9,data10,data11,data12,data13,data14])

# %%
ipldata_bowlers.corr()
# Out:
# C:\Users\a\AppData\Local\Temp\ipykernel_11580\483439996.py:1: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   ipldata_bowlers.corr()
#            POS       Mat      Inns        Ov      Runs      Wkts       Avg  \
# POS   1.000000 -0.695649 -0.838900 -0.871605 -0.850773 -0.921321  0.496889
# Mat  -0.695649  1.000000  0.904504  0.818629  0.798178  0.709030 -0.161822
# Inns -0.838900  0.904504  1.000000  0.961407  0.944192  0.832776 -0.174332
# Ov   -0.871605  0.818629  0.961407  1.000000  0.972969  0.883025 -0.219897
# Runs -0.850773  0.798178  0.944192  0.972969  1.000000  0.856908 -0.155936
# Wkts -0.921321  0.709030  0.832776  0.883025  0.856908  1.000000 -0.454600
# Avg   0.496889 -0.161822 -0.174332 -0.219897 -0.155936 -0.454600  1.000000
# ...

# %%
ipldata_batters.ndim
# Out:
# 2

# %%
ipldata_bowlers.ndim
# Out:
# 2

# %%
ipldata_bowlers.duplicated().sum()
# Out:
# 0

# %%
ipldata_batters.duplicated().sum()
# Out:
# 0

# %%
ipldata_batters.isnull().sum()
# Out:
# POS       0
# Player    0
# Mat       0
# Inns      0
# NO        0
# Runs      0
# HS        0
# Avg       0
# BF        0
# SR        0
# 100       0
# 50        0
# 4s        0
# 6s        0
# dtype: int64

# %%
ipldata_bowlers.isnull().sum()
# Out:
# POS       0
# Player    0
# Mat       0
# Inns      0
# Ov        0
# Runs      0
# Wkts      0
# BBI       0
# Avg       0
# Econ      0
# SR        0
# 4w        0
# 5w        0
# dtype: int64

# %%
ipldata_bowlers.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 615 entries, 0 to 102
# Data columns (total 13 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   POS     615 non-null    int64
#  1   Player  615 non-null    object
#  2   Mat     615 non-null    int64
#  3   Inns    615 non-null    int64
#  4   Ov      615 non-null    float64
#  5   Runs    615 non-null    int64
#  6   Wkts    615 non-null    int64
#  7   BBI     615 non-null    object
#  8   Avg     615 non-null    float64
#  9   Econ    615 non-null    float64
#  10  SR      615 non-null    float64
#  11  4w      615 non-null    int64
#  12  5w      615 non-null    int64
# dtypes: float64(4), int64(7), object(2)
# memory usage: 67.3+ KB

# %%
combined_data = pd.DataFrame()

# %%
#filtering th data
bowling_data= ipldata_bowlers[['Player', 'Wkts']]

# %%
bowler_stats = bowling_data.groupby('Player').agg({'Wkts': 'sum'})

# %%
combined_data = combined_data.append(bowling_data)
# Out:
# C:\Users\a\AppData\Local\Temp\ipykernel_11580\1020350507.py:1: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   combined_data = combined_data.append(bowling_data)

# %%
bowler_wickets = combined_data.groupby('Player')['Wkts'].sum()

# %%
top_bowlers = bowler_wickets.nlargest(12)

# %%
top_bowlers
# Out:
# Player
# Jasprit Bumrah       134
# Yuzvendra Chahal     131
# Rashid Khan          112
# Kagiso Rabada         99
# Bhuvneshwar Kumar     92
# Mohammad Shami        91
# Trent Boult           83
# Shardul Thakur        81
# Dwayne Bravo          78
# Sunil Narine          78
# Sandeep Sharma        75
# Andre Russell         73
# Name: Wkts, dtype: int64

# %%
bowling_data= ipldata_bowlers[['Player', 'Wkts']]
trend=bowling_data.value_counts()['Jasprit Bumrah']
# year=[2016,2017,2018,2019,2020,2021]
wkt=trend.index
plt.plot(trend.index)

# %%
bowling_data= ipldata_bowlers[['Player', 'Wkts']]
trend=bowling_data.value_counts()['Yuzvendra Chahal']
# year=[2016,2017,2018,2019,2020,2021]
wkt=trend.index
plt.plot(trend.index)

# %%
bowling_data= ipldata_bowlers[['Player', 'Wkts']]
trend=bowling_data.value_counts()['Rashid Khan']
# year=[2016,2017,2018,2019,2020,2021]
wkt=trend.index
plt.plot(trend.index)

# %%
bowling_data= ipldata_bowlers[['Player', 'Wkts']]
trend=bowling_data.value_counts()['Kagiso Rabada']
# year=[2016,2017,2018,2019,2020,2021]
wkt=trend.index
plt.plot(trend.index)

# %%
bowling_data= ipldata_bowlers[['Player', 'Wkts']]
trend=bowling_data.value_counts()['Bhuvneshwar Kumar']
# year=[2016,2017,2018,2019,2020,2021]
wkt=trend.index
plt.plot(trend.index)

# %%
bowling_data= ipldata_bowlers[['Player', 'Wkts']]
trend=bowling_data.value_counts()['Mohammad Shami']
# year=[2016,2017,2018,2019,2020,2021]
wkt=trend.index
plt.plot(trend.index)

# %%
bowling_data= ipldata_bowlers[['Player', 'Wkts']]
trend=bowling_data.value_counts()['Trent Boult']
# year=[2016,2017,2018,2019,2020,2021]
wkt=trend.index
plt.plot(trend.index)

# %%
bowling_data= ipldata_bowlers[['Player', 'Wkts']]
trend=bowling_data.value_counts()['Shardul Thakur']
# year=[2016,2017,2018,2019,2020,2021]
wkt=trend.index
plt.plot(trend.index)

# %%
bowling_data= ipldata_bowlers[['Player', 'Wkts']]
trend=bowling_data.value_counts()['Dwayne Bravo']
# year=[2016,2017,2018,2019,2020,2021]
wkt=trend.index
plt.plot(trend.index)

# %%
bowling_data= ipldata_bowlers[['Player', 'Wkts']]
trend=bowling_data.value_counts()['Sunil Narine']
# year=[2016,2017,2018,2019,2020,2021]
wkt=trend.index
plt.plot(trend.index)

# %%
bowling_data= ipldata_bowlers[['Player', 'Wkts']]
trend=bowling_data.value_counts()['Sandeep Sharma']
# year=[2016,2017,2018,2019,2020,2021]
wkt=trend.index
plt.plot(trend.index)

# %%
bowling_data= ipldata_bowlers[['Player', 'Wkts']]
trend=bowling_data.value_counts()['Andre Russell']
# year=[2016,2017,2018,2019,2020,2021]
wkt=trend.index
plt.plot(trend.index)
